# %% [markdown]
# # Scraper for the MICI website

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://idblegacy.iadb.org/en/mici/by-country,7631.html?status=&country=url.country&yearDate=&page="

# %%
def get_page_content(url):
    """
        Given a url, this would return the html content of the page parsed by BeautifulSoup
    """
    page = requests.get(url)
    page_content = BeautifulSoup(page.content, 'html.parser')
    return page_content

# %%
def get_last_page_number():
    """
        Finds the last page number in the pagination to help in navigation of projects
    """
    url = "https://idblegacy.iadb.org/en/mici/by-country,7631.html"
    page_content = get_page_content(url)
    return page_content.find('a',text='Last ')['href'].split('=')[-1]

# %%
def get_project_links(url):
    """
        Given a url, finds the links to projects listed in the page
        
    """
    page_content = get_page_content(url)
    search_results = page_content.find(id="searchResults")
    return search_results.find_all('li')

# %%
def get_project_name_and_id(link):
    """
        finds the project name and project ID from a project URL
        
        For example:
        link = <a href="/en/mici/complaint-detail,19172.html?ID=MICI-BID-BR-2018-0132" style="cursor:pointer;">
                    São José dos Campos Urban Structuring Program-Request II (MICI-BID-BR-2018-0132)
                </a>
        project name = São José dos Campos Urban Structuring Program-Request II
        project id = MICI-BID-BR-2018-0132
                    
    """
    project_link = link.find('a')
    project_link_text = project_link.getText()
    project_name = project_link_text.split("(")[0].strip()
    project_id = project_link_text.split("(")[1].replace(")","").strip()
    return project_name, project_id

# %%
def get_country_year_info(link):
    """
        given the project link, finds the country and year info from a div element inner to it.
        
        For example:
            <span class="smaller9 removeMarginBottom" style="width:345px; float:left;"> 
                Brazil - 2018 
            </span>
        country = Brazil
        year = 2018
        
    """
    div = link.find('div')
    country_year_info = div.find_all('span')[0].getText()
    return country_year_info.split("-")

# %%
def get_project_status(link):
    """
        given the project link, extracts the status info from it.
        
        for example:
            <span class="smaller9 removeMarginBottom" style="width:345px; float:left;">
                Status: <b>Closed</b> 
            </span>
        status = closed
    """
    div = link.find('div')
    status = div.find_all('span')[1].getText().split(":")[1].strip()
    return status

# %%
def get_detailed_project_url(link):
    """
        Generates the link to the individual project given the <a href></a> element
        For example:
            <a href="/en/mici/complaint-detail,19172.html?ID=MICI-BID-BR-2018-0132">
        
        returns: https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-BID-BR-2018-0132
    """
    base_url = "https://idblegacy.iadb.org"
    href = link.find('a').get('href')
    return base_url + href

# %%
def get_additional_project_info(project_page):
    """
        From the project page, extract additional project information 
        For example:
        <div class="detailboxContent">
            <b>Project Number:</b>
            <p>BR-L1160</p> 
            <b>Environmental Category:</b> <p> B </p>
            <b> Project Name: </b> <p> São José dos Campos Urban Structuring Program </p>
            <b> Sector: </b> <p> URBAN DEVELOPMENT AND HOUSING </p> 
            <b> Project Type: </b> <p> Loan Operation </p> 
            <b> IDB Financing: </b> <p> USD 85,672,400 </p> 
        </div>
        
        From this we can extract additional info about the project such as Project Number, Environmental category etc.,
    """
    additional_project_info = {}
    try:
        detailed_project_content = project_page.find("div", {"class": "detailboxContent"})
        project_info_keys = [b.getText().strip() for b in detailed_project_content.find_all('b')]
        project_info_values = [p.getText().strip() for p in detailed_project_content.find_all('p')]
        additional_project_info = dict(zip(project_info_keys, project_info_values))
        print additional_project_info
    except:
        pass
    return additional_project_info

# %%
def update_additional_project_info(additional_project_info, project_details):
    """
        Updates the project details object with the additional project information 
        got from the method "get_additional_project_info"
    """
    project_details["project_number"] = additional_project_info.get("Project Number:")
    project_details["environmental_category"] = additional_project_info.get("Environmental Category:")
    project_details["project_company"] = None
    project_details["Project Type:"] = additional_project_info.get("Project Type:")
    project_details["sector"] = additional_project_info.get("Sector:")
    project_details["issues"] = None
    project_details["financial_institution"] = None
    project_details["financing"] = additional_project_info.get("IDB Financing:")
    project_details["related_project_number"] = additional_project_info.get("Other related projects:")

# %%
def get_stage_names(project_year):
    """
        Returns the sub stages that project lifecycle is comprised. 
        It is modeled slightly different for project before and after 2014. 
        
        Example project before 2014:
        https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=ME-MICI002-2012
        
        Example project after 2014: 
        https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-BID-BR-2018-0132
    """
    if project_year > 2014:
         return ["Registration", "Eligibility", "Assessment", "Consultation Phase", "DR-Monitoring", 
                      "Recommendation for a CR and ToRs", "Investigation", "CR Report", "CR-Monitoring"]
    else:
        return ["DR-Eligibility", "Assessment", "Consultation Phase Exercise", "DR-Monitoring", "CR-Eligibility",
                      "Preparation of TORs", "Investigation", "Panel Report", "CR-Monitoring"]

# %%
def get_project_stage_elements(project_year, project_page):
    """
        The html elements that have the project stage information is different for project before and after 2014.
        This method extracts the project stage related html elements based on the project year. 
    """
    project_stage_elements = []
    if project_year > 2014:
        project_stage_table = project_page.find("tr", {"class":"cuadro_dw_gris"})
        project_stage_elements = project_stage_table.find_all("td")
    else:
        project_stage_table = project_page.find("div", {"class": "tabla_principal"})
        project_stage_divs = project_stage_table.find_all("div")
        project_stage_elements = []
        for stage_div in project_stage_divs:
            if 'cuadro_up_' in stage_div.get('class')[0]:
                project_stage_elements.append(stage_div)
    return project_stage_elements

# %%
def get_completed_stage_css_class(project_year):
    """
        the css class of the html elements are the indicators that tell if the project stage has started/ended.
        This differs for projects before and after 2014. 
        This method returns the expected css class values for each project stage to know it it has started/ended
    """
    if project_year > 2014:
        return ["sltgray", "sltgray", "sltgreen", "sltgreen", "sltgreen", "cuadro_dw_azul",
                                     "cuadro_dw_azul", "cuadro_dw_azul", "cuadro_dw_azul"]
    else:
        return ["cuadro_up_ok" for i in xrange(9)]

# %%
def get_project_stages_current_state(project_year, project_page):
    """
        this method updates the state of every stage in the project by comparing the css class value of the stage with
        the expected css value.
    """
    project_stages_current_state = {}
    stage_names = get_stage_names(project_year)
    project_stage_elements = get_project_stage_elements(project_year, project_page)
    completed_stage_css_class = get_completed_stage_css_class(project_year)
    
    for i in xrange(len(project_stage_elements)):
        if completed_stage_css_class[i] in project_stage_elements[i].get('class'):
            project_stages_current_state[stage_names[i]] = True

    return project_stages_current_state

# %%
def update_stage_info(stage, start_date_key, end_date_key, project_stages_current_state):
    """
        updates the start end and end date completion for a given stage, 
        if project_stages_current_state has the corresponding start date / end date key is set to True
        
        For example:
        Dispute Resolution stage is said to be started when the project is in Assesment phase
        so, if "Assesment" is set to True in project_stages_current_state,
        project_details[dispute_resolution_start_date] will be set to "completed"
        
    """
    if project_stages_current_state.get(start_date_key):
        project_details[stage + "_start_date"] = "completed"
    if project_stages_current_state.get(end_date_key):
        project_details[stage + "_end_date"] = "completed"

# %%
def update_project_stage_completion_info(project_year, project_stages_current_state, project_details):
    """
        There are 5 high level stages in a project, namely:
            1. Registration
            2. Eligibility
            3. Monitoring
            4. Dispute Resolution
            5. Compliance Review
            
            Based on the current state information obtained for each project stage, 
            we update if the start and end date has been completed for that stage. 
            
            This logic differs for projects before and after 2014 as we know the stages are named
            slightly different respectively. 
        
    """
    STAGE_COMPLETED = "completed"
    project_stage_completetion_info = {}
    
    if project_year > 2014:
        update_stage_info("registration", "Registration",  "Eligibility", project_stages_current_state, project_details)
        update_stage_info("eligibility", "Eligibility",  "", project_stages_current_state, project_details)
        update_stage_info("monitoring", "",  "DR-Monitoring", project_stages_current_state, project_details)
        update_stage_info("monitoring", "",  "CR-Monitoring", project_stages_current_state, project_details)
        update_stage_info("dispute_resolution", "Assessment",  "Consultation Phase", project_stages_current_state, project_details)
        update_stage_info("compliance_review", "Recommendation for a CR and ToRs",  "CR Report", project_stages_current_state, project_details)
        
        if project_details["status"] == "closed":
            project_stage_completetion_info["monitoring_end_date"] = STAGE_COMPLETED
    else:
        update_stage_info("registration", "",  "", project_stages_current_state, project_details)
        update_stage_info("eligibility", "",  "DR-Eligibility", project_stages_current_state, project_details)
        update_stage_info("eligibility", "",  "CR-Eligibility", project_stages_current_state, project_details)
        update_stage_info("monitoring", "",  "DR-Monitoring", project_stages_current_state, project_details)
        update_stage_info("monitoring", "",  "CR-Monitoring", project_stages_current_state, project_details)
        update_stage_info("dispute_resolution", "Assessment",  "Consultation Phase Exercise", project_stages_current_state, project_details)
        update_stage_info("compliance_review", "Preparation of TORs",  "Panel Report", project_stages_current_state, project_details)
    
    
    return project_stage_completetion_info

# %%
project_list = []
last_page_number = int(get_last_page_number(page_content))

for page_number in xrange(1, last_page_number):
    
    url = base_url + str(page_number)
    
    project_links = get_project_links(url)

    for link in project_links:
        project_details = {}

        # update IAM info
        project_details["IAM"] = "MICI"
        project_details["IAM_id"] = 24

        # update project name, id info
        project_details["project_name"], project_details["project_id"]  = get_project_name_and_id(link)

        # update country, year info
        project_details["country"], project_details["year"] = get_country_year_info(link)
        
        print "Scraping project details for %s - %s - %s - %s", (project_details["project_name"],
                                                                 project_details["project_id"],
                                                                 project_details["country"],
                                                                 project_details["year"])
        
        # hack 
        if project_details["project_id"] == "MICI-AR-2015-0084":
            project_details["year"] = 2015

        # update Status
        project_details["status"] = get_project_status(link)

        # TODO: update filer info

        # update detailed project link
        project_details["Hyperlink"] = project_url
        
        # fetching and updating additional project info from the project page
        project_url = get_detailed_project_url(link)
        project_page = get_page_content(project_url)
        additional_project_info = get_additional_project_info(project_page)
        update_additional_project_info(additional_project_info, project_details)

        # fetching and updating start / end date completion for every stage of the project
        get_project_stage_current_details(int(project_details["year"]), project_page)
        update_project_stage_info(project_stage_current_details)

        project_details["Date Closed"] = "completed" if project_details["status"] =="Closed" else None
        
        # TODO
        project_details["Documents"] = None
        
        project_list.append(project_details)
        
        print "************************************************************************************"
# Out:
# project IAM: MICI
# project IAM id 24
# project name: Rural Land Titling & Registration Project in Peru - Third Phase
# project id PTRT-3
# country, year :   Peru - 2015
# status :  Open
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-PE-2015-0094
# project number :  PE-L1026
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_end_date': 'completed', 'DR_start_date': 'completed', 'monitoring_start_date': 'completed', 'eligibility_start_date': 'completed', 'registration_start_date': 'completed', 'DR_end_date': 'completed'}
# registration_start_date completed
# registration_end_date completed
# eligibility_start_date completed
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date completed
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Blumenau's Sustainable Urban Mobility Program
# project id MICI-BR-2015-0093
# country, year :   Brazil - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-BR-2015-0093
# project number :  BR-L1272
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_end_date': 'completed', 'registration_start_date': 'completed', 'eligibility_start_date': 'completed'}
# registration_start_date completed
# registration_end_date completed
# eligibility_start_date completed
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Program to Support Production Development for International Integration
# project id MICI-ES-2015-0092
# country, year :   El Salvador - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-ES-2015-0092
# project number :  ES-L1057
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_start_date': 'completed'}
# registration_start_date completed
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Bayport Colombia: Financial Inclusion for BOP Public Employees
# project id MICI-CO-2015-0091
# country, year :   Colombia - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-CO-2015-0091
# project number :  CO-L1147
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_end_date': 'completed', 'registration_start_date': 'completed', 'eligibility_start_date': 'completed'}
# registration_start_date completed
# registration_end_date completed
# eligibility_start_date completed
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Mario Covas Rodoanel Project - Northern Section - Request II
# project id MICI-BR-2015-0090
# country, year :   Brazil - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-BR-2015-0090
# project number :  BR-L1296
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_start_date': 'completed'}
# registration_start_date completed
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Productive Infrastructure Program III
# project id MICI-HA-2015-0089
# country, year :   Haiti - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-HA-2015-0089
# project number :  HA-L1091
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_start_date': 'completed'}
# registration_start_date completed
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Mario Covas Rodoanel Project - Northern Section
# project id MICI-BR-2015-0088
# country, year :   Brazil - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-BR-2015-0088
# project number :  BR-L1296
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_start_date': 'completed'}
# registration_start_date completed
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Support to Improve Sustainability of the Electricity Service
# project id MICI-SU-2015-0087
# country, year :   Suriname - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-SU-2015-0087
# project number :  SU-L1009
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_start_date': 'completed'}
# registration_start_date completed
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Transmission System Support in Paraguay
# project id MICI-PR-2015-0086
# country, year :   Paraguay - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-PR-2015-0086
# project number :  PR-L1058
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_start_date': 'completed'}
# registration_start_date completed
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Strategic Public Transportation Systems
# project id SPTS
# country, year :   Colombia - 2015
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-CO-2015-0085
# project number :  CO-L1091
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_start_date': 'completed'}
# registration_start_date completed
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Integrated Urban Solid Waste Management
# project id MICI-AR-2015-0084
# country, year :   Argentina - 2014
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail,19172.html?ID=MICI-AR-2015-0084
# project number :  AR-L1025
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'registration_start_date': 'completed'}
# registration_start_date completed
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date None
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: AUSA Road Safety and Urban Mobility Program
# project id MICI-AR-2014-081
# country, year :   Argentina - 2014
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=MICI-AR-2014-081
# project number :  AR-L1166
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Etileno XXI
# project id MICI-ME-2014-080
# country, year :   Mexico - 2014
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=MICI-ME-2014-080
# project number :  ME-L1110
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: La Paz Storm Drainage Program II
# project id MICI-BO-2014-079
# country, year :   Bolivia - 2014
# status :  Open
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=MICI-BO-2014-079
# project number :  BO-L1028
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Blumenau Urban Sustainable Mobility Program, on behalf of 800 residents of the neighborhood of Ponta Aguda in Blumenau
# project id MICI-BR-2014-078
# country, year :   Brazil - 2014
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=MICI-BR-2014-078
# project number :  BR-L1272
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Drainage, roads, water supply and sewerage in the low areas of Belem
# project id MICI-BR-2013-076
# country, year :   Brazil - 2013
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=MICI-BR-2013-076
# project number :  BR0055
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Support for the Sustainable Development of the Interior
# project id MICI-SU-2013-069
# country, year :   Suriname - 2013
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=MICI-SU-2013-069
# project number :  SU-T1026
# environmental_category :  None
# project_company :  None
# Project Type: :  Technical Cooperation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Sustainable Environmental Urban Management Program for the Reconquista River Basin-Province of Buenos Aires
# project id MICI-AR-2013-070
# country, year :   Argentina - 2013
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=MICI-AR-2013-070
# project number :  AR-L1121
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Blumenau Urban Sustainable Mobility Program
# project id MICI-BR-2013-068
# country, year :   Brazil - 2013
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=MICI-BR-2013-068
# project number :  BR-L1272
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Mareña Renovables Wind Project
# project id ME-MICI002-2012
# country, year :   Mexico - 2012
# status :  Open
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=ME-MICI002-2012
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Agrifood Health and Quality Management Program
# project id CCLIP
# country, year :   Argentina - 2012
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=AR-MICI004-2012
# project number :  AR-L1032
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_end_date': 'completed', 'DR_start_date': 'completed', 'monitoring_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date completed
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Panama Canal Expansion Program
# project id PN-MICI002-2011
# country, year :   Panama - 2011
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=PN-MICI002-2011
# project number :  PN-L1032
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: El Dorado International Airport
# project id CO-MICI002-2011
# country, year :   Colombia - 2011
# status :  Open
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=CO-MICI002-2011
# project number :  CO-L1029
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed', 'DR_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: San Francisco-Mocoa Alternate Road Construction Project - Phase I
# project id CO-MICI001-2011
# country, year :   Colombia - 2011
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=CO-MICI001-2011
# project number :  CO-L1019
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Mário Covas Rodoanel - Northern Sections 1 and 2
# project id BR-MICI005-2011
# country, year :   Brazil - 2011
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=BR-MICI005-2011
# project number :  BR-L1296
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Termoeléctrica del Golfo Project
# project id ME-MICI001-2011
# country, year :   Mexico - 2011
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=ME-MICI001-2011
# project number :  ME0218
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Low-Income Neighborhood Improvement Program – Habitar
# project id BR-MICI004-2011
# country, year :   Brazil - 2011
# status :  Open
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=BR-MICI004-2011
# project number :  BR0273
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed', 'DR_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: São José dos Campos Urban Structuring Program
# project id BR-MICI006-2011
# country, year :   Brazil - 2011
# status :  Open
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=BR-MICI006-2011
# project number :  BR-L1160
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed', 'DR_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Mario Covas Rodoanel Project - Northern Section 1
# project id BR-MICI003-2011
# country, year :   Brazil - 2011
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=BR-MICI003-2011
# project number :  BR-L1296
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Santa Barbara-Rurrenabaque Northern Corridor Highway Improvement Program
# project id BO-MICI001-2011
# country, year :   Bolivia - 2011
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=BO-MICI001-2011
# project number :  BO-L1011
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed', 'DR_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Electric Interconnection System for the Central American Countries
# project id SIEPAC
# country, year :   Costa Rica - 2010
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=CR-MICI001-2010
# project number :  CR-L1009
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_end_date': 'completed', 'DR_start_date': 'completed', 'monitoring_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date completed
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Argentina - Programa de Mejoramiento de Barrios II
# project id PROMEBA II
# country, year :   Argentina - 2010
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=AR-MICI003-2010
# project number :  AR-L1019
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Program to Improve Highway Corridors in Paraguay
# project id PR-MICI002-2010
# country, year :   Paraguay - 2010
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=PR-MICI002-2010
# project number :  PR0035
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Provincial Agricultural Services Program II
# project id PROSAP II
# country, year :   Argentina - 2010
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=AR-MICI002-2010
# project number :  AR-L1030
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed', 'DR_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Estrada Nova Watershed Sanitation
# project id PROMABEN
# country, year :   Brazil - 2010
# status :  Closed
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=BR-MICI002-2010
# project number :  BR-L1065
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_end_date': 'completed', 'DR_start_date': 'completed', 'monitoring_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date completed
# ************************************************************************************
# project IAM: MICI
# project IAM id 24
# project name: Multiphase Development Infrastructure Program: Support Production in Entre Ríos
# project id AR-MICI001-2010
# country, year :   Argentina - 2010
# status :  Open
# detailed project url https://idblegacy.iadb.org/en/mici/complaint-detail-2014,1804.html?ID=AR-MICI001-2010
# project number :  AR-L1036
# environmental_category :  None
# project_company :  None
# Project Type: :  Loan Operation
# sector :  None
# financing :  None
# related_project_number :  None
# issues :  None
# financial_institution :  None
# get_project_stage_completion_info
# {'eligibility_end_date': 'completed', 'DR_start_date': 'completed', 'DR_end_date': 'completed'}
# registration_start_date None
# registration_end_date None
# eligibility_start_date None
# eligibility_end_date completed
# dispute_resolution_start_date None
# dispute_resolution_end_date None
# compliance_review_start_date None
# compliance_review_end_date None
# monitoring_start_date None
# monitoring_end_date None
# ************************************************************************************
