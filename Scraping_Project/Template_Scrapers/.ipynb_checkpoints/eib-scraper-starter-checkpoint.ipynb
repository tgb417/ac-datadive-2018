# %% [markdown]
# # Starter for the EIB website

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "http://www.eib.org/about/accountability/complaints/cases/index.htm"

# %%
html, sc = get_page_content(base_url)

# %%
def get_page_content(url):
    """
        Given a url, this would return the html content of the page parsed by BeautifulSoup
    """
    page = requests.get(url)
    page_content = BeautifulSoup(page.content, 'html.parser')
    return page_content, page.status_code

# %%
def get_project_table(html):
    """
        Grab the table with project information
    """
    maindiv = html.find("div", {"id": "consultationsList"})
    table= maindiv.find_all('table')
    df = pd.read_html(str(table), header=0)
    df = df[0]
    return df

# %%
def get_project_urls(html):
    """
    Retrieve the urls from the onclick js function
    """
    maindiv = html.find("div", {"id": "consultationsList"})
    trs = maindiv.find_all('tr')
    urls = []
    for i in trs:
        if i.get('onclick'):
            url = i.get('onclick').split(',')[0].replace("window.open('/"'',"").strip('\'').strip()
            url = 'http://' + url
            urls.append(url)
    return urls

# %% [markdown]
# **Scrape**

# %%
def scrape():
    ## GET PROJECT TABLE
    df = get_project_table(html)
    ## GET URLS
    urls = get_project_urls(html)
    df['urls'] = urls

    ## Limit to E type
    df = df[df.Type == 'E']

    def clean(x):
        return x.replace(':','').strip()

    ## Store the project specific data
    ## Only grabbing Filer/ID right now - but should be expanded
    project_data = []
    count404 = 0
    url404 = []
    
    ## Iterate over urls - controlling for 404 errors
    for idx, url in zip(df.index,df.urls):
        page, sc = get_page_content(url)
        if sc != 404:
            main_section = page.find('div',{'id':'consultations'})
            project_id = main_section.find('strong',text='Reference').next_sibling
            filer = main_section.find('strong',text='Complainant').next_sibling
            project_data.append([idx, clean(project_id), clean(filer)])
        else:
            count404 += 1
            url404.append(url)
            project_data.append([idx, None, None])
    
    print('Number of 404 Responses', count404)
    
    ## Merge into DF and return 
    project_data = pd.DataFrame(project_data,columns=['idx','project id','Filer(s)'])
    project_data.index = project_data.idx
    project_data = project_data.drop('idx',axis=1)
    df = pd.concat([df, project_data],axis=1)
    return df, {'url404':url404, 'count404':count404}

# %%
df = scrape()

# %%
df
# Out:
#     Received Date Type                                   Case Name  \
# idx
# 0      28/09/2009    E                Gazela Bridge Rehabilitation
# 2      07/11/2008    E                    Transport Lending Policy
# 7      19/05/2009    E                     South Sinai Power Plant
# 8      13/02/2012    E                        Autoroute Sfax-Gabes
# 9      26/10/2010    E                                    MOZAL II
# 15     05/01/2012    E                Cairo Metro Line 3 (Phase 3)
# 32     12/07/2012    E                              DTS Expressway
# 33     02/05/2012    E                  Eastern Poland Roads Ten-T
# 49     19/10/2012    E          ICL Specialty Chemicals R&D (RSFF)
# 58     26/05/2012    E             Larnaca Sewerage and Drainage I
# 59     17/07/2013    E                       Mauritius Waste Water
# 60     09/10/2013    E         Medio Ambiente Water Infrastructure
# 61     14/05/2014    E              Mediterranean Railway Corridor
# 65     01/03/2012    E  Municipal and Regional Infrastructure Loan
# 66     07/12/2012    E                         N11-N7 Motorway PPP
# 79     09/05/2012    E                            Poland Motorways
# 82     08/11/2011    E                             Porto De Aveiro
# 86     16/07/2013    E                           Puerto de Sevilla
# 87     22/10/2013    E                      Railroad Gilje-Paracin
# 90     06/07/2012    E                Rivne-Kyiv High Voltage Line
# 102    16/07/2013    E                 Terminal Contenedores Cadiz
# 103    03/01/2012    E                 Terminal Contenedores Cadiz
# 107    14/12/2012    E                      Transit Roads V Lot 17
# 110    13/04/2012    E    Valencia Centros Escolares II-1 and II-2
# 111    14/03/2012    E                        Waste Disposal Plant
# 114    30/09/2011    E                     Roads Rehabilitation VI
# 115    18/05/2011    E                            KTK Motorway PPP
# 116    02/05/2011    E                      Portuguese Dam Program
# 117    14/07/2010    E                     Ecocimento Fibre Cement
# 118    06/07/2010    E                   Gipuzkoa Waste Management
# ..            ...  ...                                         ...
# 554    06/12/2017    E                     Trans Adriatic Pipeline
# 555    07/12/2017    E           Regional Mombasa Port Access Road
# 556    07/12/2017    E                     Trans Adriatic Pipeline
# 557    07/12/2017    E                     Trans Adriatic Pipeline
# 558    07/12/2017    E                     Trans Adriatic Pipeline
# 559    13/12/2017    E                     Trans Adriatic Pipeline
# 561    14/12/2017    E                Cairo Metro Line 3 (Phase 3)
# 564    08/01/2018    E                    S3 Doublement de la MC27
# 565    19/01/2018    E                     Trans Adriatic Pipeline
# 566    19/01/2018    E                     Trans Adriatic Pipeline
# 567    21/01/2018    E                     Trans Adriatic Pipeline
# 568    20/01/2018    E                     Trans Adriatic Pipeline
# 569    20/01/2018    E                     Trans Adriatic Pipeline
# 570    29/01/2018    E                     Trans Adriatic Pipeline
# 571    01/02/2018    E                     Trans Adriatic Pipeline
# 573    04/02/2018    E                     Trans Adriatic Pipeline
# 574    05/02/2018    E                     Trans Adriatic Pipeline
# 575    06/02/2018    E                     Trans Adriatic Pipeline
# 578    09/02/2018    E                     Trans Adriatic Pipeline
# 580    02/02/2018    E              Spain Gas Network Expansion II
# 581    05/02/2018    E              Spain Gas Network Expansion II
# 582    06/02/2018    E              Spain Gas Network Expansion II
# 583    14/02/2018    E              Spain Gas Network Expansion II
# 584    16/02/2018    E              Spain Gas Network Expansion II
# 585    03/12/2013    E              Castor Underground Gas Storage
# 586    23/02/2018    E              Spain Gas Network Expansion II
# 587    28/02/2018    E              Spain Gas Network Expansion II
# 588    01/03/2018    E              Spain Gas Network Expansion II
# 589    02/03/2018    E              Spain Gas Network Expansion II
# 594    12/04/2018    E     Grand Contournement Ouest de Strasbourg
#
#     Country/Territory                                        Allegations  \
# idx
# 0              Serbia                       Social impact of the project
# 2             Unknown  Failure to consult the public on EIB Transport...
# 7               Egypt          Negative environmental and social impacts
# 8             Tunisia     Violation of the legal expropriation procedure
# 9          Mozambique               Breach of EIB environmental policies
# 15              Egypt  The promoter ignores the complainants' request...
# 32             Poland           Failure to comply with environmental law
# 33             Poland  Failure to mitigate project impacts regarding ...
# 49              Spain  Negative environmental impacts of the subsidia...
# 58             Cyprus  Environmental compliance of the project; misma...
# 59          Mauritius                     Non-respect of security norms.
# 60              Spain  Alleged concerns over possible construction of...
# 61              Spain  Failure to carry out proper consultation and e...
# 65             Serbia    Failure to comply with the EIB social standards
# 66            Ireland  Too low traffic flows and low project returns ...
# 79             Poland       Failure to comply with the environmental law
# 82           Portugal  Improper design for the extension of the North...
# 86              Spain  Negative environmental impacts of the deep dre...
# 87             Serbia       Concerns regarding the expropriation of land
# 90            Ukraine  Failure to comply with EIB's project cycle; fa...
# 102             Spain  Environmental issues related to the new contai...
# 103             Spain  Alleged negative environmental impact of the p...
# 107          Bulgaria  Poor quality of works in project implementatio...
# 110             Spain  Educational facilities have become substandard...
# 111           Croatia      Negative environmental impacts of the project
# 114           Romania  Overflooding rainwarer following road rehabili...
# 115            Greece  Breach of EU and national law in the field of ...
# 116          Portugal  Concerns about the financial and technical via...
# 117        Mozambique  Purchase of asbestos contaminated property due...
# 118             Spain  Alleged negative impact of the Gipuzkoa Waste ...
# ..                ...                                                ...
# 554             Italy  Alleged safety issues and militarization of th...
# 555             Kenya           Inadequate compensation after demolition
# 556             Italy  Negative environmental, social and economic im...
# 557             Italy  Negative environmental, social and economic im...
# 558             Italy  Alleged serious infringements by TAP on the te...
# 559             Italy  Alleged serious environmental risks and negati...
# 561             Egypt  Inadequate compensation in relation to resettl...
# 564           Tunisia  Alleged negative environmental impacts of the ...
# 565             Italy  Alleged negative environmental, social and eco...
# 566             Italy  Alleged negative environmental, social and eco...
# 567             Italy  Alleged negative environmental, social and eco...
# 568             Italy  Alleged negative environmental, social and eco...
# 569             Italy  Alleged negative environmental, social and eco...
# 570             Italy  Alleged negative environmental, social and eco...
# 571             Italy  Alleged negative environmental, social and eco...
# 573            Greece  Alleged safety issues with the project impleme...
# 574             Italy  Alleged negative environmental, social and eco...
# 575             Italy  Alleged dangerousness of the project and reque...
# 578             Italy  Alleged elevated health and safety risks of th...
# 580             Spain  Non-compliance with EIB policies and applicabl...
# 581             Spain  Non-compliance with EIB policies and applicabl...
# 582             Spain  Non-compliance with EIB policies and applicabl...
# 583             Spain  Non-compliance with EIB policies and applicabl...
# 584             Spain  Non-compliance with EIB policies and applicabl...
# 585             Spain  Alleged failure to assess the environmental an...
# 586             Spain  Non-compliance with EIB policies and applicabl...
# 587             Spain  Non-compliance with EIB policies and applicabl...
# 588             Spain  Non-compliance with EIB policies and applicabl...
# 589             Spain  Non-compliance with EIB policies and applicabl...
# 594            France                     Negative environmental impacts
#
#     Last Stage Completed Current Status  \
# idx
# 0             16/07/2010         Closed
# 2             15/04/2009         Closed
# 7             27/04/2010         Closed
# 8             25/11/2013         Closed
# 9             04/05/2012         Closed
# 15            09/03/2014         Closed
# 32            04/03/2014         Closed
# 33            18/01/2013         Closed
# 49            06/09/2013         Closed
# 58            04/03/2014         Closed
# 59            17/09/2013         Closed
# 60            29/11/2013         Closed
# 61            11/06/2014         Closed
# 65            15/05/2014         Closed
# 66            19/12/2013         Closed
# 79            05/09/2013         Closed
# 82            12/10/2012         Closed
# 86            07/07/2014         Closed
# 87            23/12/2013         Closed
# 90            14/01/2013         Closed
# 102           21/11/2013         Closed
# 103           12/10/2012         Closed
# 107           18/06/2014         Closed
# 110           11/02/2013         Closed
# 111           28/06/2013         Closed
# 114           25/01/2013         Closed
# 115           27/12/2013         Closed
# 116           13/07/2011         Closed
# 117           28/07/2010  Admissibility
# 118           12/03/2014         Closed
# ..                   ...            ...
# 554                  NaN     Assessment
# 555                  NaN     Assessment
# 556                  NaN     Assessment
# 557                  NaN     Assessment
# 558                  NaN     Assessment
# 559                  NaN     Assessment
# 561                  NaN     Assessment
# 564                  NaN     Assessment
# 565                  NaN     Assessment
# 566                  NaN     Assessment
# 567                  NaN     Assessment
# 568                  NaN     Assessment
# 569                  NaN     Assessment
# 570                  NaN     Assessment
# 571                  NaN     Assessment
# 573                  NaN     Assessment
# 574                  NaN     Assessment
# 575                  NaN     Assessment
# 578                  NaN     Assessment
# 580                  NaN     Assessment
# 581                  NaN     Assessment
# 582                  NaN     Assessment
# 583                  NaN     Assessment
# 584                  NaN     Assessment
# 585           23/03/2018         Closed
# 586                  NaN     Assessment
# 587                  NaN     Assessment
# 588                  NaN     Assessment
# 589                  NaN     Assessment
# 594           12/04/2018  Admissibility
#
#                                                   urls  \
# idx
# 0    http://eib.org/about/accountability/complaints...
# 2    http://eib.org/about/accountability/complaints...
# 7    http://eib.org/about/accountability/complaints...
# 8    http://eib.org/about/accountability/complaints...
# 9    http://eib.org/about/accountability/complaints...
# 15   http://eib.org/about/accountability/complaints...
# 32   http://eib.org/about/accountability/complaints...
# 33   http://eib.org/about/accountability/complaints...
# 49   http://eib.org/about/accountability/complaints...
# 58   http://eib.org/about/accountability/complaints...
# 59   http://eib.org/about/accountability/complaints...
# 60   http://eib.org/about/accountability/complaints...
# 61   http://eib.org/about/accountability/complaints...
# 65   http://eib.org/about/accountability/complaints...
# 66   http://eib.org/about/accountability/complaints...
# 79   http://eib.org/about/accountability/complaints...
# 82   http://eib.org/about/accountability/complaints...
# 86   http://eib.org/about/accountability/complaints...
# 87   http://eib.org/about/accountability/complaints...
# 90   http://eib.org/about/accountability/complaints...
# 102  http://eib.org/about/accountability/complaints...
# 103  http://eib.org/about/accountability/complaints...
# 107  http://eib.org/about/accountability/complaints...
# 110  http://eib.org/about/accountability/complaints...
# 111  http://eib.org/about/accountability/complaints...
# 114  http://eib.org/about/accountability/complaints...
# 115  http://eib.org/about/accountability/complaints...
# 116  http://eib.org/about/accountability/complaints...
# 117  http://eib.org/about/accountability/complaints...
# 118  http://eib.org/about/accountability/complaints...
# ..                                                 ...
# 554  http://eib.org/about/accountability/complaints...
# 555  http://eib.org/about/accountability/complaints...
# 556  http://eib.org/about/accountability/complaints...
# 557  http://eib.org/about/accountability/complaints...
# 558  http://eib.org/about/accountability/complaints...
# 559  http://eib.org/about/accountability/complaints...
# 561  http://eib.org/about/accountability/complaints...
# 564  http://eib.org/about/accountability/complaints...
# 565  http://eib.org/about/accountability/complaints...
# 566  http://eib.org/about/accountability/complaints...
# 567  http://eib.org/about/accountability/complaints...
# 568  http://eib.org/about/accountability/complaints...
# 569  http://eib.org/about/accountability/complaints...
# 570  http://eib.org/about/accountability/complaints...
# 571  http://eib.org/about/accountability/complaints...
# 573  http://eib.org/about/accountability/complaints...
# 574  http://eib.org/about/accountability/complaints...
# 575  http://eib.org/about/accountability/complaints...
# 578  http://eib.org/about/accountability/complaints...
# 580  http://eib.org/about/accountability/complaints...
# 581  http://eib.org/about/accountability/complaints...
# 582  http://eib.org/about/accountability/complaints...
# 583  http://eib.org/about/accountability/complaints...
# 584  http://eib.org/about/accountability/complaints...
# 585  http://eib.org/about/accountability/complaints...
# 586  http://eib.org/about/accountability/complaints...
# 587  http://eib.org/about/accountability/complaints...
# 588  http://eib.org/about/accountability/complaints...
# 589  http://eib.org/about/accountability/complaints...
# 594  http://eib.org/about/accountability/complaints...
#
#                     project id  \
# idx
# 0                         None
# 2                 SG/E/2008/06
# 7                 SG/E/2009/05
# 8                 SG/E/2012/01
# 9                 SG/E/2010/16
# 15                SG/E/2012/12
# 32                SG/E/2012/10
# 33                SG/E/2012/06
# 49                SG/E/2012/11
# 58                SG/E/2012/07
# 59             SG/E/2013/04/PR
# 60             SG/E/2013/08/PR
# 61             SG/E/2014/05/PR
# 65                SG/E/2012/02
# 66                SG/E/2012/14
# 79                SG/E/2012/09
# 82                SG/E/2011/16
# 86                SG/E/2013/09
# 87                SG/E/2013/10
# 90                SG/E/2012/08
# 102  SG/E/2013/03/Confirmatory
# 103               SG/E/2011/18
# 107               SG/E/2012/13
# 110               SG/E/2012/05
# 111               SG/E/2012/03
# 114               SG/E/2011/12
# 115               SG/E/2011/09
# 116            SG/E/2011/07/PR
# 117               SG/E/2010/08
# 118               SG/E/2010/05
# ..                         ...
# 554               SG/E/2017/45
# 555               SG/E/2017/46
# 556               SG/E/2017/47
# 557               SG/E/2017/48
# 558               SG/E/2017/49
# 559               SG/E/2017/50
# 561               SG/E/2017/53
# 564               SG/E/2018/01
# 565               SG/E/2018/02
# 566               SG/E/2018/06
# 567               SG/E/2018/04
# 568               SG/E/2018/03
# 569               SG/E/2018/07
# 570               SG/E/2018/08
# 571               SG/E/2018/09
# 573               SG/E/2018/12
# 574               SG/E/2018/10
# 575               SG/E/2018/11
# 578               SG/E/2018/19
# 580               SG/E/2018/13
# 581               SG/E/2018/14
# 582               SG/E/2018/15
# 583               SG/E/2018/17
# 584               SG/E/2018/18
# 585               SG/E/2013/12
# 586               SG/E/2018/20
# 587               SG/E/2018/21
# 588               SG/E/2018/22
# 589               SG/E/2018/23
# 594               SG/E/2018/26
#
#                                               Filer(s)
# idx
# 0                                                 None
# 2    Mrs. Anna Roggenbuck (CEE Bankwatch) and Mrs. ...
# 7    Members of the Nuweiba Community - managers/ow...
# 8                                Abdelhamid Bouchanoua
# 9    Coalition of Mozambican NGOs (Justiça Ambienta...
# 15
# 32   The association ‘Stowarzyszenie Gliwiczanie dl...
# 33                                        Confidential
# 49
# 58                                    Antonio Serraino
# 59   An individual from Mauritius, via Mr. Lucas Ha...
# 60                                        Confidential
# 61                                        Confidential
# 65                                  Oliver Stoiljkovic
# 66                                 Individual, Ireland
# 79                                  Individual, Poland
# 82
# 86                                        Confidential
# 87
# 90   National Ecological Center of Ukraine, a membe...
# 102                   Teresa Vassallo and Marc Bugnard
# 103             Teresa Vasallo Varela and Marc Bugnard
# 107                      NGO Layers against corruption
# 110  The Complainant has waived the right to confid...
# 111                                       Confidential
# 114                                Individual, Romania
# 115                                       Confidential
# 116  GEOTA, Grupo de Estudos de Ordenamento do Terr...
# 117
# 118
# ..                                                 ...
# 554                                       Confidential
# 555                                       Confidential
# 556                                       Confidential
# 557                                       Confidential
# 558                                       Confidential
# 559                                       Confidential
# 561                                       Confidential
# 564                                       Confidential
# 565                                       Confidential
# 566                                       Confidential
# 567                                       Confidential
# 568                                       Confidential
# 569                                       Confidential
# 570                                       Confidential
# 571                                       Confidential
# 573                                       Confidential
# 574                                       Confidential
# 575                                       Confidential
# 578                                       Confidential
# 580                                       Confidential
# 581                                       Confidential
# 582                                       Confidential
# 583                                       Confidential
# 584                                       Confidential
# 585  Plataforma Ciutadana en Defensa de les Terres ...
# 586                                       Confidential
# 587                                       Confidential
# 588                                       Confidential
# 589                                       Confidential
# 594                                       Confidential
#
# [202 rows x 10 columns]
